# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd

s1 = [20, 15, 10, 25, 30, 35, 28, 40, 45, 60]
scores1 = pd.Series(s1)
print(scores1)
# Out:
# 0    20
# 1    15
# 2    10
# 3    25
# 4    30
# 5    35
# 6    28
# 7    40
# 8    45
# 9    60
# dtype: int64

# %%
plt.figure(figsize=(6,2))
plt.title("boxplot for batsman scores")
plt.xlabel("scores")
plt.boxplot(scores1,vert = False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1d76c838fb0>,
#   <matplotlib.lines.Line2D at 0x1d76c8392b0>],
#  'caps': [<matplotlib.lines.Line2D at 0x1d76c7feea0>,
#   <matplotlib.lines.Line2D at 0x1d76c8397f0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1d76c7fcdd0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1d76c839a90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1d76c839d90>],
#  'means': []}

# %%
s2 = [20,15,10,25,30,35,28,40,45,60,120,150]
scores2 = pd.Series(s2)
print(scores2)

plt.figure(figsize=(6,2))
plt.title("boxplot for batsman scores")
plt.xlabel("scores")
plt.boxplot(scores2,vert = False)
# Out:
# 0      20
# 1      15
# 2      10
# 3      25
# 4      30
# 5      35
# 6      28
# 7      40
# 8      45
# 9      60
# 10    120
# 11    150
# dtype: int64
# {'whiskers': [<matplotlib.lines.Line2D at 0x1d76cf72c30>,
#   <matplotlib.lines.Line2D at 0x1d76cf72ea0>],
#  'caps': [<matplotlib.lines.Line2D at 0x1d76cf73140>,
#   <matplotlib.lines.Line2D at 0x1d76cf73440>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1d76cf72570>],
#  'medians': [<matplotlib.lines.Line2D at 0x1d76cf73740>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1d76cf73980>],
#  'means': []}
